# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.patheffects as pe

# %%
mnsol_mnmodel1_pred = np.load("./Saved/CIGIN/mnsol_mnmodel1_pred.npy")
mnsol_mnmodel2_pred = np.load("./Saved/CIGIN/mnsol_mnmodel2_pred.npy")
mnsol_mnmodel3_pred = np.load("./Saved/CIGIN/mnsol_mnmodel3_pred.npy")
mnsol_mnmodel4_pred = np.load("./Saved/CIGIN/mnsol_mnmodel4_pred.npy")
mnsol_mnmodel5_pred = np.load("./Saved/CIGIN/mnsol_mnmodel5_pred.npy")

# %%
fsol_mnmodel1_pred = np.load("./Saved/CIGIN/fsol_mnmodel1_pred.npy")
fsol_mnmodel2_pred = np.load("./Saved/CIGIN/fsol_mnmodel2_pred.npy")
fsol_mnmodel3_pred = np.load("./Saved/CIGIN/fsol_mnmodel3_pred.npy")
fsol_mnmodel4_pred = np.load("./Saved/CIGIN/fsol_mnmodel4_pred.npy")
fsol_mnmodel5_pred = np.load("./Saved/CIGIN/fsol_mnmodel5_pred.npy")

# %%
csol_mnmodel1_pred = np.load("./Saved/CIGIN/csol_mnmodel1_pred.npy")
csol_mnmodel2_pred = np.load("./Saved/CIGIN/csol_mnmodel2_pred.npy")
csol_mnmodel3_pred = np.load("./Saved/CIGIN/csol_mnmodel3_pred.npy")
csol_mnmodel4_pred = np.load("./Saved/CIGIN/csol_mnmodel4_pred.npy")
csol_mnmodel5_pred = np.load("./Saved/CIGIN/csol_mnmodel5_pred.npy")

# %%
mnsol_mnmodel_pred = 0.2*(np.array(mnsol_mnmodel1_pred)[:,1] + np.array(mnsol_mnmodel2_pred)[:,1] + np.array(mnsol_mnmodel3_pred)[:,1] +
                          np.array(mnsol_mnmodel4_pred)[:,1] + np.array(mnsol_mnmodel5_pred)[:,1])
mnsol_mnmodel_orig = 0.2*(np.array(mnsol_mnmodel1_pred)[:,2] + np.array(mnsol_mnmodel2_pred)[:,2] + np.array(mnsol_mnmodel3_pred)[:,2] +
                          np.array(mnsol_mnmodel4_pred)[:,2] + np.array(mnsol_mnmodel5_pred)[:,2])

csol_mnmodel_pred = 0.2*(np.array(csol_mnmodel1_pred)[:,1] + np.array(csol_mnmodel2_pred)[:,1] + np.array(csol_mnmodel3_pred)[:,1] +
                          np.array(csol_mnmodel4_pred)[:,1] + np.array(csol_mnmodel5_pred)[:,1])
csol_mnmodel_orig = 0.2*(np.array(csol_mnmodel1_pred)[:,2] + np.array(csol_mnmodel2_pred)[:,2] + np.array(csol_mnmodel3_pred)[:,2] +
                          np.array(csol_mnmodel4_pred)[:,2] + np.array(csol_mnmodel5_pred)[:,2])

fsol_mnmodel_pred = 0.2*(np.array(fsol_mnmodel1_pred)[:,1] + np.array(fsol_mnmodel2_pred)[:,1] + np.array(fsol_mnmodel3_pred)[:,1] +
                          np.array(fsol_mnmodel4_pred)[:,1] + np.array(fsol_mnmodel5_pred)[:,1])
fsol_mnmodel_orig = 0.2*(np.array(fsol_mnmodel1_pred)[:,2] + np.array(fsol_mnmodel2_pred)[:,2] + np.array(fsol_mnmodel3_pred)[:,2] +
                          np.array(fsol_mnmodel4_pred)[:,2] + np.array(fsol_mnmodel5_pred)[:,2])

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 6))
ax[0].scatter(mnsol_mnmodel_orig, mnsol_mnmodel_pred)
ax[0].plot(np.linspace(-34, 7, 100), np.linspace(-34, 7, 100), lw = 1, ls = "--", c = "#ffa62b", dashes=(6, 2),
        path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])
ax[1].scatter(fsol_mnmodel_orig, fsol_mnmodel_pred)
ax[1].plot(np.linspace(-25, 7, 100), np.linspace(-25, 7, 100), lw = 1, ls = "--", c = "#ffa62b", dashes=(6, 2),
        path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])

ax[2].scatter(csol_mnmodel_orig, csol_mnmodel_pred)
ax[2].plot(np.linspace(-25, 7, 100), np.linspace(-25, 7, 100), lw = 1, ls = "--", c = "#ffa62b", dashes=(6, 2),
        path_effects=[pe.Stroke(linewidth=1.5, foreground='k'), pe.Normal()])

ax[0].set_xlim([-25, 7])
ax[0].set_ylim([-25, 7])

ax[1].set_xlim([-25, 7])
ax[1].set_ylim([-25, 7])

ax[2].set_xlim([-25, 7])
ax[2].set_ylim([-25, 7])

#Ticker(ax[0])
ax[0].set_xlabel(r"$\rm \Delta G_{solv}^{Experimental}(kcal/mol)$", fontsize = 30)
ax[0].set_ylabel(r"$\rm \Delta G_{solv}^{Predicted}(kcal/mol)$", fontsize = 30)


fig.tight_layout()

# %%
mnsol_fmodel1_pred = np.load("./Saved/CIGIN/mnsol_fmodel1_pred.npy")
mnsol_fmodel2_pred = np.load("./Saved/CIGIN/mnsol_fmodel2_pred.npy")
mnsol_fmodel3_pred = np.load("./Saved/CIGIN/mnsol_fmodel3_pred.npy")
mnsol_fmodel4_pred = np.load("./Saved/CIGIN/mnsol_fmodel4_pred.npy")
mnsol_fmodel5_pred = np.load("./Saved/CIGIN/mnsol_fmodel5_pred.npy")

# %%
fsol_fmodel1_pred = np.load("./Saved/CIGIN/fsol_fmodel1_pred.npy")
fsol_fmodel2_pred = np.load("./Saved/CIGIN/fsol_fmodel2_pred.npy")
fsol_fmodel3_pred = np.load("./Saved/CIGIN/fsol_fmodel3_pred.npy")
fsol_fmodel4_pred = np.load("./Saved/CIGIN/fsol_fmodel4_pred.npy")
fsol_fmodel5_pred = np.load("./Saved/CIGIN/fsol_fmodel5_pred.npy")

# %%
csol_fmodel1_pred = np.load("./Saved/CIGIN/csol_fmodel1_pred.npy")
csol_fmodel2_pred = np.load("./Saved/CIGIN/csol_fmodel2_pred.npy")
csol_fmodel3_pred = np.load("./Saved/CIGIN/csol_fmodel3_pred.npy")
csol_fmodel4_pred = np.load("./Saved/CIGIN/csol_fmodel4_pred.npy")
csol_fmodel5_pred = np.load("./Saved/CIGIN/csol_fmodel5_pred.npy")

# %%
csol_fmodel_pred = 0.2*(np.array(csol_fmodel1_pred)[:,1] + np.array(csol_fmodel2_pred)[:,1] + np.array(csol_fmodel3_pred)[:,1] +
                          np.array(csol_fmodel4_pred)[:,1] + np.array(csol_fmodel5_pred)[:,1])
csol_fmodel_orig = 0.2*(np.array(csol_fmodel1_pred)[:,2] + np.array(csol_fmodel2_pred)[:,2] + np.array(csol_fmodel3_pred)[:,2] +
                          np.array(csol_fmodel4_pred)[:,2] + np.array(csol_fmodel5_pred)[:,2])

fsol_fmodel_pred = 0.2*(np.array(fsol_fmodel1_pred)[:,1] + np.array(fsol_fmodel2_pred)[:,1] + np.array(fsol_fmodel3_pred)[:,1] +
                          np.array(fsol_fmodel4_pred)[:,1] + np.array(fsol_fmodel5_pred)[:,1])
fsol_fmodel_orig = 0.2*(np.array(fsol_fmodel1_pred)[:,2] + np.array(fsol_fmodel2_pred)[:,2] + np.array(fsol_fmodel3_pred)[:,2] +
                          np.array(fsol_fmodel4_pred)[:,2] + np.array(fsol_fmodel5_pred)[:,2])

mnsol_fmodel_pred = 0.2*(np.array(mnsol_fmodel1_pred)[:,1] + np.array(mnsol_fmodel2_pred)[:,1] + np.array(mnsol_fmodel3_pred)[:,1] +
                          np.array(mnsol_fmodel4_pred)[:,1] + np.array(mnsol_fmodel5_pred)[:,1])
mnsol_fmodel_orig = 0.2*(np.array(mnsol_fmodel1_pred)[:,2] + np.array(mnsol_fmodel2_pred)[:,2] + np.array(mnsol_fmodel3_pred)[:,2] +
                          np.array(mnsol_fmodel4_pred)[:,2] + np.array(mnsol_fmodel5_pred)[:,2])

# %%
mnsol_cmodel1_pred = np.load("./Saved/CIGIN/mnsol_cmodel1_pred.npy")
mnsol_cmodel2_pred = np.load("./Saved/CIGIN/mnsol_cmodel2_pred.npy")
mnsol_cmodel3_pred = np.load("./Saved/CIGIN/mnsol_cmodel3_pred.npy")
mnsol_cmodel4_pred = np.load("./Saved/CIGIN/mnsol_cmodel4_pred.npy")
mnsol_cmodel5_pred = np.load("./Saved/CIGIN/mnsol_cmodel5_pred.npy")

# %%
fsol_cmodel1_pred = np.load("./Saved/CIGIN/fsol_cmodel1_pred.npy")
fsol_cmodel2_pred = np.load("./Saved/CIGIN/fsol_cmodel2_pred.npy")
fsol_cmodel3_pred = np.load("./Saved/CIGIN/fsol_cmodel3_pred.npy")
fsol_cmodel4_pred = np.load("./Saved/CIGIN/fsol_cmodel4_pred.npy")
fsol_cmodel5_pred = np.load("./Saved/CIGIN/fsol_cmodel5_pred.npy")

# %%
csol_cmodel1_pred = np.load("./Saved/CIGIN/csol_cmodel1_pred.npy")
csol_cmodel2_pred = np.load("./Saved/CIGIN/csol_cmodel2_pred.npy")
csol_cmodel3_pred = np.load("./Saved/CIGIN/csol_cmodel3_pred.npy")
csol_cmodel4_pred = np.load("./Saved/CIGIN/csol_cmodel4_pred.npy")
csol_cmodel5_pred = np.load("./Saved/CIGIN/csol_cmodel5_pred.npy")

# %%
mnsol_cmodel_pred = 0.2*(np.array(mnsol_cmodel1_pred)[:,1] + np.array(mnsol_cmodel2_pred)[:,1] + np.array(mnsol_cmodel3_pred)[:,1] +
                          np.array(mnsol_cmodel4_pred)[:,1] + np.array(mnsol_cmodel5_pred)[:,1])
mnsol_cmodel_orig = 0.2*(np.array(mnsol_cmodel1_pred)[:,2] + np.array(mnsol_cmodel2_pred)[:,2] + np.array(mnsol_cmodel3_pred)[:,2] +
                          np.array(mnsol_cmodel4_pred)[:,2] + np.array(mnsol_cmodel5_pred)[:,2])
fsol_cmodel_pred = 0.2*(np.array(fsol_cmodel1_pred)[:,1] + np.array(fsol_cmodel2_pred)[:,1] + np.array(fsol_cmodel3_pred)[:,1] +
                          np.array(fsol_cmodel4_pred)[:,1] + np.array(fsol_cmodel5_pred)[:,1])
fsol_cmodel_orig = 0.2*(np.array(fsol_cmodel1_pred)[:,2] + np.array(fsol_cmodel2_pred)[:,2] + np.array(fsol_cmodel3_pred)[:,2] +
                          np.array(fsol_cmodel4_pred)[:,2] + np.array(fsol_cmodel5_pred)[:,2])
csol_cmodel_pred = 0.2*(np.array(csol_cmodel1_pred)[:,1] + np.array(csol_cmodel2_pred)[:,1] + np.array(csol_cmodel3_pred)[:,1] +
                          np.array(csol_cmodel4_pred)[:,1] + np.array(csol_cmodel5_pred)[:,1])
csol_cmodel_orig = 0.2*(np.array(csol_cmodel1_pred)[:,2] + np.array(csol_cmodel2_pred)[:,2] + np.array(csol_cmodel3_pred)[:,2] +
                          np.array(csol_cmodel4_pred)[:,2] + np.array(csol_cmodel5_pred)[:,2])

# %%
fig, ax[2] = plt.subplots(1, 3, figsize=(20, 6), sharey=True)

ax[2][0].plot(np.linspace(-34, 7, 100), np.linspace(-34, 7, 100), lw = 2.5, ls = "--", c = "#ffa62b", dashes=(6, 2),
        path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[2][0].scatter(mnsol_cmodel_orig, mnsol_cmodel_pred, c = "#0485D1", s = 75, lw = 1)
r2_val = r2_score(mnsol_cmodel_orig, mnsol_cmodel_pred)
mse = mean_squared_error(mnsol_cmodel_orig, mnsol_cmodel_pred)
ax[2][0].text(x = -23.1, y = 3, s = f"$R^2 = {np.round(r2_val,3)}$" , fontsize = 22)
ax[2][0].text(x = -23.1, y = 0, s = f"MSE = {np.round(mse,3)}(kcal/mol)", fontsize = 22)

ax[2][1].plot(np.linspace(-34, 7, 100), np.linspace(-34, 7, 100), lw = 2.5, ls = "--", c = "#ffa62b", dashes=(6, 2),
        path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[2][1].scatter(fsol_cmodel_orig, fsol_cmodel_pred, c = "#0485D1", s = 75, lw = 1)
r2_val = r2_score(fsol_cmodel_orig, fsol_cmodel_pred)
mse = mean_squared_error(fsol_cmodel_orig, fsol_cmodel_pred)
ax[2][1].text(x = -23.1, y = 3, s = f"$R^2 = {np.round(r2_val,3)}$" , fontsize = 22)
ax[2][1].text(x = -23.1, y = 0, s = f"MSE = {np.round(mse,3)}(kcal/mol)", fontsize = 22)

ax[2][2].scatter(csol_cmodel_orig, csol_cmodel_pred, c = "#FF028D", s = 75, lw = 1)
ax[2][2].plot(np.linspace(-34, 7, 100), np.linspace(-34, 7, 100), lw = 2.5, ls = "--", c = "#ffa62b", dashes=(6, 2),
        path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
r2_val = r2_score(csol_cmodel_orig, csol_cmodel_pred)
mse = mean_squared_error(csol_cmodel_orig, csol_cmodel_pred)
ax[2][2].text(x = -23.1, y = 3, s = f"$R^2 = {np.round(r2_val,3)}$" , fontsize = 22)
ax[2][2].text(x = -23.1, y = 0, s = f"MSE = {np.round(mse,3)}(kcal/mol)", fontsize = 22)


ax[2][0].set_xlim([-25, 7])
ax[2][0].set_ylim([-25, 7])

ax[2][1].set_xlim([-25, 7])
ax[2][1].set_ylim([-25, 7])

ax[2][2].set_xlim([-25, 7])
ax[2][2].set_ylim([-25, 7])

# Ticker(ax[2][0])
# Ticker(ax[2][1])
# Ticker(ax[2][2])
ax[2][0].set_xlabel(r"$\rm \Delta G_{solv}^{Experimental}(kcal/mol)$", fontsize = 30)
ax[2][1].set_xlabel(r"$\rm \Delta G_{solv}^{Experimental}(kcal/mol)$", fontsize = 30)
ax[2][2].set_xlabel(r"$\rm \Delta G_{solv}^{Experimental}(kcal/mol)$", fontsize = 30)
ax[2][0].set_ylabel(r"$\rm \Delta G_{solv}^{Predicted}(kcal/mol)$", fontsize = 30)
fig.tight_layout()

# %%
plt.style.use('../../../CVSampler/NoteBooks/style.txt')

# %%
fig, ax = plt.subplots(figsize=(8, 6))

r2_val_mnsol_mnmodel = r2_score(mnsol_mnmodel_orig, mnsol_mnmodel_pred)
mse_mnsol_mnmodel = mean_squared_error(mnsol_mnmodel_orig, mnsol_mnmodel_pred)

r2_val_fsol_mnmodel = r2_score(fsol_mnmodel_orig, fsol_mnmodel_pred)
mse_fsol_mnmodel = mean_squared_error(fsol_mnmodel_orig, fsol_mnmodel_pred)

r2_val_csol_mnmodel = r2_score(csol_mnmodel_orig, csol_mnmodel_pred)
mse_csol_mnmodel = mean_squared_error(csol_mnmodel_orig, csol_mnmodel_pred)

r2_val_mnsol_fmodel = r2_score(mnsol_fmodel_orig, mnsol_fmodel_pred)
mse_mnsol_fmodel = mean_squared_error(mnsol_fmodel_orig, mnsol_fmodel_pred)

r2_val_fsol_fmodel = r2_score(fsol_fmodel_orig, fsol_fmodel_pred)
mse_fsol_fmodel = mean_squared_error(fsol_fmodel_orig, fsol_fmodel_pred)

r2_val_csol_fmodel = r2_score(csol_fmodel_orig, csol_fmodel_pred)
mse_csol_fmodel = mean_squared_error(csol_fmodel_orig, csol_fmodel_pred)

r2_val_mnsol_cmodel = r2_score(mnsol_cmodel_orig, mnsol_cmodel_pred)
mse_mnsol_cmodel = mean_squared_error(mnsol_cmodel_orig, mnsol_cmodel_pred)

r2_val_fsol_cmodel = r2_score(fsol_cmodel_orig, fsol_cmodel_pred)
mse_fsol_cmodel = mean_squared_error(fsol_cmodel_orig, fsol_cmodel_pred)

r2_val_csol_cmodel = r2_score(csol_cmodel_orig, csol_cmodel_pred)
mse_csol_cmodel = mean_squared_error(csol_cmodel_orig, csol_cmodel_pred)

ax.bar([0.25, 0.50, 0.75], [mse_mnsol_mnmodel, mse_fsol_mnmodel, mse_csol_mnmodel],
       width=0.2, lw = 1, color = ['royalblue', 'lime', 'hotpink'], label = ["MNSol","FreeSolv", "CombiSolv"])
ax.bar(np.array([0.25, 0.50, 0.75])+1.0, [mse_mnsol_fmodel, mse_fsol_fmodel, mse_csol_fmodel],
       width=0.2, lw = 1, color = ['royalblue', 'lime', 'hotpink'])
ax.bar(np.array([0.25, 0.50, 0.75])+2.0, [mse_mnsol_cmodel, mse_fsol_cmodel, mse_csol_cmodel],
       width=0.2, lw = 1, color = ['royalblue', 'lime', 'hotpink'], zorder = 1)
ax.fill_between([0, 1], 0, 7, color = "royalblue", alpha = 0.3, zorder = -1)
ax.fill_between([1, 2], 0, 7, color = "lime", alpha = 0.3, zorder = -1)
ax.fill_between([2, 3], 0, 7, color = "hotpink", alpha = 0.3, zorder = -1)
ax.set_xlim([0, 3])
ax.set_ylim([0, 6.25])
ax.legend(fontsize = 18, loc = "center right")
ax.text(x = 1.5, y = 6.5, s = "Trained on", ha = "center", va = "center", fontsize = 25, color = "navy")
ax.axhline(6.25, c = "navy")
ax.axvline(1.0, c = "navy", ymax = 1.0, ymin = 0)
ax.axvline(2.0,ymax = 1.0, ymin = 0, c = "navy")

ax.text(x = 0.5, y = 5.95, s = "MNSol", ha = "center", va = "center", fontsize = 20)
ax.text(x = 1.5, y = 5.95, s = "FreeSolv", ha = "center", va = "center", fontsize = 20)
ax.text(x = 2.5, y = 5.95, s = "CombiSolv", ha = "center", va = "center", fontsize = 20)
ax.set_ylabel("Mean Squared Error (kcal/mol)", fontsize = 25)
ax.set_xticks([])
fig.tight_layout()
#plt.savefig("mse_cigin_datasets.svg")

# %%
# Create a dictionary to store the data
data = {
    "Scenario": [
        "mnsol_mnmodel", "fsol_mnmodel", "csol_mnmodel",
        "mnsol_fmodel", "fsol_fmodel", "csol_fmodel",
        "mnsol_cmodel", "fsol_cmodel", "csol_cmodel"
    ],
    "MSE": [
        mse_mnsol_mnmodel, mse_fsol_mnmodel, mse_csol_mnmodel,
        mse_mnsol_fmodel, mse_fsol_fmodel, mse_csol_fmodel,
        mse_mnsol_cmodel, mse_fsol_cmodel, mse_csol_cmodel
    ],
    "R2": [
        r2_val_mnsol_mnmodel, r2_val_fsol_mnmodel, r2_val_csol_mnmodel,
        r2_val_mnsol_fmodel, r2_val_fsol_fmodel, r2_val_csol_fmodel,
        r2_val_mnsol_cmodel, r2_val_fsol_cmodel, r2_val_csol_cmodel
    ]
}

# Create the DataFrame
results_df = pd.DataFrame(data)

# Display the DataFrame
print(results_df)
# Out:
#         Scenario       MSE        R2
# 0  mnsol_mnmodel  0.785880  0.959761
# 1   fsol_mnmodel  1.803964  0.878166
# 2   csol_mnmodel  5.478851  0.777643
# 3   mnsol_fmodel  1.329850  0.931909
# 4    fsol_fmodel  0.366262  0.975264
# 5    csol_fmodel  3.008408  0.877905
# 6   mnsol_cmodel  2.225229  0.886064
# 7    fsol_cmodel  0.480982  0.967516
# 8    csol_cmodel  0.366311  0.985133

# %%
print(results_df.to_latex())
# Out:
# \begin{tabular}{llrr}
# \toprule
#  & Scenario & MSE & R2 \\
# \midrule
# 0 & mnsol_mnmodel & 0.785880 & 0.959761 \\
# 1 & fsol_mnmodel & 1.803964 & 0.878166 \\
# 2 & csol_mnmodel & 5.478851 & 0.777643 \\
# 3 & mnsol_fmodel & 1.329850 & 0.931909 \\
# 4 & fsol_fmodel & 0.366262 & 0.975264 \\
# 5 & csol_fmodel & 3.008408 & 0.877905 \\
# 6 & mnsol_cmodel & 2.225229 & 0.886064 \\
# 7 & fsol_cmodel & 0.480982 & 0.967516 \\
# 8 & csol_cmodel & 0.366311 & 0.985133 \\
# \bottomrule
# \end{tabular}
